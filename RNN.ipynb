# %% [markdown]
# # Tutorial on RNN with NLTK
# https://rguigoures.github.io/word2vec_pytorch/

# %%
import re
import nltk
import itertools
import nltk
import ssl
import numpy as np

# workaround broken data import
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

#nltk.download("brown")

from nltk.corpus import brown
from collections import Counter
import random, math

# %%
corpus = []

for cat in ['news']:
    for text_id in brown.fileids(cat):
        raw_text = list(itertools.chain.from_iterable(brown.sents(text_id)))
        text = ' '.join(raw_text)
        text = text.lower()
        text.replace('\n', ' ')
        text = re.sub('[^a-z ]+', '', text)
        corpus.append([w for w in text.split() if w != ''])
len(corpus[1])
# Out:
# 1972

# %%
def subsample_frequent_words(corpus):
    filtered_corpus = []
    word_counts = dict(Counter(list(itertools.chain.from_iterable(corpus))))
    sum_word_counts = sum(list(word_counts.values()))
    word_counts = {word: word_counts[word]/float(sum_word_counts) for word in word_counts}
    for text in corpus:
        filtered_corpus.append([])
        for word in text:
            if random.random() < (1+math.sqrt(word_counts[word] * 1e3)) * 1e-3 / float(word_counts[word]):
                filtered_corpus[-1].append(word)
    return filtered_corpus
corpus = subsample_frequent_words(corpus)
print(len(corpus[1]))
# Out:
# 1542

# %%
vocabulary = set(itertools.chain.from_iterable(corpus))

word_to_index = {w: idx for (idx, w) in enumerate(vocabulary)}
index_to_word = {idx: w for (idx, w) in enumerate(vocabulary)}

# %%
context_tuple_list = []
w = 4

for text in corpus:
    for i, word in enumerate(text):
        first_context_word_index = max(0,i-w)
        last_context_word_index = min(i+w, len(text))
        for j in range(first_context_word_index, last_context_word_index):
            if i!=j:
                context_tuple_list.append((word, text[j]))
print("There are {} pairs of target and context words".format(len(context_tuple_list)))
# Out:
# There are 473679 pairs of target and context words

# %%
context_tuple_list
# Out:
# [('fulton', 'county'),
#  ('fulton', 'grand'),
#  ('fulton', 'jury'),
#  ('county', 'fulton'),
#  ('county', 'grand'),
#  ('county', 'jury'),
#  ('county', 'friday'),
#  ('grand', 'fulton'),
#  ('grand', 'county'),
#  ('grand', 'jury'),
#  ('grand', 'friday'),
#  ('grand', 'an'),
#  ('jury', 'fulton'),
#  ('jury', 'county'),
#  ('jury', 'grand'),
#  ('jury', 'friday'),
#  ('jury', 'an'),
#  ('jury', 'investigation'),
#  ('friday', 'fulton'),
#  ('friday', 'county'),
#  ('friday', 'grand'),
#  ('friday', 'jury'),
#  ('friday', 'an'),
#  ('friday', 'investigation'),
#  ('friday', 'atlantas'),
#  ('an', 'county'),
#  ('an', 'grand'),
#  ('an', 'jury'),
#  ('an', 'friday'),
#  ('an', 'investigation'),
#  ('an', 'atlantas'),
#  ('an', 'recent'),
#  ('investigation', 'grand'),
#  ('investigation', 'jury'),
#  ('investigation', 'friday'),
#  ('investigation', 'an'),
#  ('investigation', 'atlantas'),
#  ('investigation', 'recent'),
#  ('investigation', 'primary'),
#  ('atlantas', 'jury'),
#  ('atlantas', 'friday'),
#  ('atlantas', 'an'),
#  ('atlantas', 'investigation'),
#  ('atlantas', 'recent'),
#  ('atlantas', 'primary'),
#  ('atlantas', 'election'),
#  ('recent', 'friday'),
#  ('recent', 'an'),
#  ('recent', 'investigation'),
#  ('recent', 'atlantas'),
#  ('recent', 'primary'),
#  ('recent', 'election'),
#  ('recent', 'produced'),
#  ('primary', 'an'),
#  ('primary', 'investigation'),
#  ('primary', 'atlantas'),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('primary', 'produced'),
#  ('primary', 'no'),
#  ('election', 'investigation'),
#  ('election', 'atlantas'),
#  ('election', 'recent'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('election', 'no'),
#  ('election', 'evidence'),
#  ('produced', 'atlantas'),
#  ('produced', 'recent'),
#  ('produced', 'primary'),
#  ('produced', 'election'),
#  ('produced', 'no'),
#  ('produced', 'evidence'),
#  ('produced', 'any'),
#  ('no', 'recent'),
#  ('no', 'primary'),
#  ('no', 'election'),
#  ('no', 'produced'),
#  ('no', 'evidence'),
#  ('no', 'any'),
#  ('no', 'irregularities'),
#  ('evidence', 'primary'),
#  ('evidence', 'election'),
#  ('evidence', 'produced'),
#  ('evidence', 'no'),
#  ('evidence', 'any'),
#  ('evidence', 'irregularities'),
#  ('evidence', 'took'),
#  ('any', 'election'),
#  ('any', 'produced'),
#  ('any', 'no'),
#  ('any', 'evidence'),
#  ('any', 'irregularities'),
#  ('any', 'took'),
#  ('any', 'place'),
#  ('irregularities', 'produced'),
#  ('irregularities', 'no'),
#  ('irregularities', 'evidence'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('irregularities', 'place'),
#  ('irregularities', 'jury'),
#  ('took', 'no'),
#  ('took', 'evidence'),
#  ('took', 'any'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('took', 'jury'),
#  ('took', 'further'),
#  ('place', 'evidence'),
#  ('place', 'any'),
#  ('place', 'irregularities'),
#  ('place', 'took'),
#  ('place', 'jury'),
#  ('place', 'further'),
#  ('place', 'termend'),
#  ('jury', 'any'),
#  ('jury', 'irregularities'),
#  ('jury', 'took'),
#  ('jury', 'place'),
#  ('jury', 'further'),
#  ('jury', 'termend'),
#  ('jury', 'presentments'),
#  ('further', 'irregularities'),
#  ('further', 'took'),
#  ('further', 'place'),
#  ('further', 'jury'),
#  ('further', 'termend'),
#  ('further', 'presentments'),
#  ('further', 'city'),
#  ('termend', 'took'),
#  ('termend', 'place'),
#  ('termend', 'jury'),
#  ('termend', 'further'),
#  ('termend', 'presentments'),
#  ('termend', 'city'),
#  ('termend', 'executive'),
#  ('presentments', 'place'),
#  ('presentments', 'jury'),
#  ('presentments', 'further'),
#  ('presentments', 'termend'),
#  ('presentments', 'city'),
#  ('presentments', 'executive'),
#  ('presentments', 'committee'),
#  ('city', 'jury'),
#  ('city', 'further'),
#  ('city', 'termend'),
#  ('city', 'presentments'),
#  ('city', 'executive'),
#  ('city', 'committee'),
#  ('city', 'which'),
#  ('executive', 'further'),
#  ('executive', 'termend'),
#  ('executive', 'presentments'),
#  ('executive', 'city'),
#  ('executive', 'committee'),
#  ('executive', 'which'),
#  ('executive', 'had'),
#  ('committee', 'termend'),
#  ('committee', 'presentments'),
#  ('committee', 'city'),
#  ('committee', 'executive'),
#  ('committee', 'which'),
#  ('committee', 'had'),
#  ('committee', 'overall'),
#  ('which', 'presentments'),
#  ('which', 'city'),
#  ('which', 'executive'),
#  ('which', 'committee'),
#  ('which', 'had'),
#  ('which', 'overall'),
#  ('which', 'charge'),
#  ('had', 'city'),
#  ('had', 'executive'),
#  ('had', 'committee'),
#  ('had', 'which'),
#  ('had', 'overall'),
#  ('had', 'charge'),
#  ('had', 'of'),
#  ('overall', 'executive'),
#  ('overall', 'committee'),
#  ('overall', 'which'),
#  ('overall', 'had'),
#  ('overall', 'charge'),
#  ('overall', 'of'),
#  ('overall', 'election'),
#  ('charge', 'committee'),
#  ('charge', 'which'),
#  ('charge', 'had'),
#  ('charge', 'overall'),
#  ('charge', 'of'),
#  ('charge', 'election'),
#  ('charge', 'deserves'),
#  ('of', 'which'),
#  ('of', 'had'),
#  ('of', 'overall'),
#  ('of', 'charge'),
#  ('of', 'election'),
#  ('of', 'deserves'),
#  ('of', 'praise'),
#  ('election', 'had'),
#  ('election', 'overall'),
#  ('election', 'charge'),
#  ('election', 'of'),
#  ('election', 'deserves'),
#  ('election', 'praise'),
#  ('election', 'thanks'),
#  ('deserves', 'overall'),
#  ('deserves', 'charge'),
#  ('deserves', 'of'),
#  ('deserves', 'election'),
#  ('deserves', 'praise'),
#  ('deserves', 'thanks'),
#  ('deserves', 'city'),
#  ('praise', 'charge'),
#  ('praise', 'of'),
#  ('praise', 'election'),
#  ('praise', 'deserves'),
#  ('praise', 'thanks'),
#  ('praise', 'city'),
#  ('praise', 'of'),
#  ('thanks', 'of'),
#  ('thanks', 'election'),
#  ('thanks', 'deserves'),
#  ('thanks', 'praise'),
#  ('thanks', 'city'),
#  ('thanks', 'of'),
#  ('thanks', 'atlanta'),
#  ('city', 'election'),
#  ('city', 'deserves'),
#  ('city', 'praise'),
#  ('city', 'thanks'),
#  ('city', 'of'),
#  ('city', 'atlanta'),
#  ('city', 'manner'),
#  ('of', 'deserves'),
#  ('of', 'praise'),
#  ('of', 'thanks'),
#  ('of', 'city'),
#  ('of', 'atlanta'),
#  ('of', 'manner'),
#  ('of', 'in'),
#  ('atlanta', 'praise'),
#  ('atlanta', 'thanks'),
#  ('atlanta', 'city'),
#  ('atlanta', 'of'),
#  ('atlanta', 'manner'),
#  ('atlanta', 'in'),
#  ('atlanta', 'which'),
#  ('manner', 'thanks'),
#  ('manner', 'city'),
#  ('manner', 'of'),
#  ('manner', 'atlanta'),
#  ('manner', 'in'),
#  ('manner', 'which'),
#  ('manner', 'the'),
#  ('in', 'city'),
#  ('in', 'of'),
#  ('in', 'atlanta'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('in', 'the'),
#  ('in', 'election'),
#  ('which', 'of'),
#  ('which', 'atlanta'),
#  ('which', 'manner'),
#  ('which', 'in'),
#  ('which', 'the'),
#  ('which', 'election'),
#  ('which', 'conducted'),
#  ('the', 'atlanta'),
#  ('the', 'manner'),
#  ('the', 'in'),
#  ('the', 'which'),
#  ('the', 'election'),
#  ('the', 'conducted'),
#  ('the', 'septemberoctober'),
#  ('election', 'manner'),
#  ('election', 'in'),
#  ('election', 'which'),
#  ('election', 'the'),
#  ('election', 'conducted'),
#  ('election', 'septemberoctober'),
#  ('election', 'term'),
#  ('conducted', 'in'),
#  ('conducted', 'which'),
#  ('conducted', 'the'),
#  ('conducted', 'election'),
#  ('conducted', 'septemberoctober'),
#  ('conducted', 'term'),
#  ('conducted', 'jury'),
#  ('septemberoctober', 'which'),
#  ('septemberoctober', 'the'),
#  ('septemberoctober', 'election'),
#  ('septemberoctober', 'conducted'),
#  ('septemberoctober', 'term'),
#  ('septemberoctober', 'jury'),
#  ('septemberoctober', 'had'),
#  ('term', 'the'),
#  ('term', 'election'),
#  ('term', 'conducted'),
#  ('term', 'septemberoctober'),
#  ('term', 'jury'),
#  ('term', 'had'),
#  ('term', 'been'),
#  ('jury', 'election'),
#  ('jury', 'conducted'),
#  ('jury', 'septemberoctober'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('jury', 'been'),
#  ('jury', 'charged'),
#  ('had', 'conducted'),
#  ('had', 'septemberoctober'),
#  ('had', 'term'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('had', 'charged'),
#  ('had', 'fulton'),
#  ('been', 'septemberoctober'),
#  ('been', 'term'),
#  ('been', 'jury'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('been', 'fulton'),
#  ('been', 'superior'),
#  ('charged', 'term'),
#  ('charged', 'jury'),
#  ('charged', 'had'),
#  ('charged', 'been'),
#  ('charged', 'fulton'),
#  ('charged', 'superior'),
#  ('charged', 'court'),
#  ('fulton', 'jury'),
#  ('fulton', 'had'),
#  ('fulton', 'been'),
#  ('fulton', 'charged'),
#  ('fulton', 'superior'),
#  ('fulton', 'court'),
#  ('fulton', 'judge'),
#  ('superior', 'had'),
#  ('superior', 'been'),
#  ('superior', 'charged'),
#  ('superior', 'fulton'),
#  ('superior', 'court'),
#  ('superior', 'judge'),
#  ('superior', 'durwood'),
#  ('court', 'been'),
#  ('court', 'charged'),
#  ('court', 'fulton'),
#  ('court', 'superior'),
#  ('court', 'judge'),
#  ('court', 'durwood'),
#  ('court', 'pye'),
#  ('judge', 'charged'),
#  ('judge', 'fulton'),
#  ('judge', 'superior'),
#  ('judge', 'court'),
#  ('judge', 'durwood'),
#  ('judge', 'pye'),
#  ('judge', 'investigate'),
#  ('durwood', 'fulton'),
#  ('durwood', 'superior'),
#  ('durwood', 'court'),
#  ('durwood', 'judge'),
#  ('durwood', 'pye'),
#  ('durwood', 'investigate'),
#  ('durwood', 'reports'),
#  ('pye', 'superior'),
#  ('pye', 'court'),
#  ('pye', 'judge'),
#  ('pye', 'durwood'),
#  ('pye', 'investigate'),
#  ('pye', 'reports'),
#  ('pye', 'of'),
#  ('investigate', 'court'),
#  ('investigate', 'judge'),
#  ('investigate', 'durwood'),
#  ('investigate', 'pye'),
#  ('investigate', 'reports'),
#  ('investigate', 'of'),
#  ('investigate', 'possible'),
#  ('reports', 'judge'),
#  ('reports', 'durwood'),
#  ('reports', 'pye'),
#  ('reports', 'investigate'),
#  ('reports', 'of'),
#  ('reports', 'possible'),
#  ('reports', 'irregularities'),
#  ('of', 'durwood'),
#  ('of', 'pye'),
#  ('of', 'investigate'),
#  ('of', 'reports'),
#  ('of', 'possible'),
#  ('of', 'irregularities'),
#  ('of', 'hardfought'),
#  ('possible', 'pye'),
#  ('possible', 'investigate'),
#  ('possible', 'reports'),
#  ('possible', 'of'),
#  ('possible', 'irregularities'),
#  ('possible', 'hardfought'),
#  ('possible', 'primary'),
#  ('irregularities', 'investigate'),
#  ('irregularities', 'reports'),
#  ('irregularities', 'of'),
#  ('irregularities', 'possible'),
#  ('irregularities', 'hardfought'),
#  ('irregularities', 'primary'),
#  ('irregularities', 'which'),
#  ('hardfought', 'reports'),
#  ('hardfought', 'of'),
#  ('hardfought', 'possible'),
#  ('hardfought', 'irregularities'),
#  ('hardfought', 'primary'),
#  ('hardfought', 'which'),
#  ('hardfought', 'won'),
#  ('primary', 'of'),
#  ('primary', 'possible'),
#  ('primary', 'irregularities'),
#  ('primary', 'hardfought'),
#  ('primary', 'which'),
#  ('primary', 'won'),
#  ('primary', 'mayornominate'),
#  ('which', 'possible'),
#  ('which', 'irregularities'),
#  ('which', 'hardfought'),
#  ('which', 'primary'),
#  ('which', 'won'),
#  ('which', 'mayornominate'),
#  ('which', 'ivan'),
#  ('won', 'irregularities'),
#  ('won', 'hardfought'),
#  ('won', 'primary'),
#  ('won', 'which'),
#  ('won', 'mayornominate'),
#  ('won', 'ivan'),
#  ('won', 'allen'),
#  ('mayornominate', 'hardfought'),
#  ('mayornominate', 'primary'),
#  ('mayornominate', 'which'),
#  ('mayornominate', 'won'),
#  ('mayornominate', 'ivan'),
#  ('mayornominate', 'allen'),
#  ('mayornominate', 'jr'),
#  ('ivan', 'primary'),
#  ('ivan', 'which'),
#  ('ivan', 'won'),
#  ('ivan', 'mayornominate'),
#  ('ivan', 'allen'),
#  ('ivan', 'jr'),
#  ('ivan', 'only'),
#  ('allen', 'which'),
#  ('allen', 'won'),
#  ('allen', 'mayornominate'),
#  ('allen', 'ivan'),
#  ('allen', 'jr'),
#  ('allen', 'only'),
#  ('allen', 'relative'),
#  ('jr', 'won'),
#  ('jr', 'mayornominate'),
#  ('jr', 'ivan'),
#  ('jr', 'allen'),
#  ('jr', 'only'),
#  ('jr', 'relative'),
#  ('jr', 'handful'),
#  ('only', 'mayornominate'),
#  ('only', 'ivan'),
#  ('only', 'allen'),
#  ('only', 'jr'),
#  ('only', 'relative'),
#  ('only', 'handful'),
#  ('only', 'of'),
#  ('relative', 'ivan'),
#  ('relative', 'allen'),
#  ('relative', 'jr'),
#  ('relative', 'only'),
#  ('relative', 'handful'),
#  ('relative', 'of'),
#  ('relative', 'such'),
#  ('handful', 'allen'),
#  ('handful', 'jr'),
#  ('handful', 'only'),
#  ('handful', 'relative'),
#  ('handful', 'of'),
#  ('handful', 'such'),
#  ('handful', 'reports'),
#  ('of', 'jr'),
#  ('of', 'only'),
#  ('of', 'relative'),
#  ('of', 'handful'),
#  ('of', 'such'),
#  ('of', 'reports'),
#  ('of', 'was'),
#  ('such', 'only'),
#  ('such', 'relative'),
#  ('such', 'handful'),
#  ('such', 'of'),
#  ('such', 'reports'),
#  ('such', 'was'),
#  ('such', 'received'),
#  ('reports', 'relative'),
#  ('reports', 'handful'),
#  ('reports', 'of'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('reports', 'received'),
#  ('reports', 'the'),
#  ('was', 'handful'),
#  ('was', 'of'),
#  ('was', 'such'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('was', 'the'),
#  ('was', 'jury'),
#  ('received', 'of'),
#  ('received', 'such'),
#  ('received', 'reports'),
#  ('received', 'was'),
#  ('received', 'the'),
#  ('received', 'jury'),
#  ('received', 'said'),
#  ('the', 'such'),
#  ('the', 'reports'),
#  ('the', 'was'),
#  ('the', 'received'),
#  ('the', 'jury'),
#  ('the', 'said'),
#  ('the', 'considering'),
#  ('jury', 'reports'),
#  ('jury', 'was'),
#  ('jury', 'received'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('jury', 'considering'),
#  ('jury', 'widespread'),
#  ('said', 'was'),
#  ('said', 'received'),
#  ('said', 'the'),
#  ('said', 'jury'),
#  ('said', 'considering'),
#  ('said', 'widespread'),
#  ('said', 'interest'),
#  ('considering', 'received'),
#  ('considering', 'the'),
#  ('considering', 'jury'),
#  ('considering', 'said'),
#  ('considering', 'widespread'),
#  ('considering', 'interest'),
#  ('considering', 'in'),
#  ('widespread', 'the'),
#  ('widespread', 'jury'),
#  ('widespread', 'said'),
#  ('widespread', 'considering'),
#  ('widespread', 'interest'),
#  ('widespread', 'in'),
#  ('widespread', 'election'),
#  ('interest', 'jury'),
#  ('interest', 'said'),
#  ('interest', 'considering'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('interest', 'election'),
#  ('interest', 'number'),
#  ('in', 'said'),
#  ('in', 'considering'),
#  ('in', 'widespread'),
#  ('in', 'interest'),
#  ('in', 'election'),
#  ('in', 'number'),
#  ('in', 'of'),
#  ('election', 'considering'),
#  ('election', 'widespread'),
#  ('election', 'interest'),
#  ('election', 'in'),
#  ('election', 'number'),
#  ('election', 'of'),
#  ('election', 'voters'),
#  ('number', 'widespread'),
#  ('number', 'interest'),
#  ('number', 'in'),
#  ('number', 'election'),
#  ('number', 'of'),
#  ('number', 'voters'),
#  ('number', 'the'),
#  ('of', 'interest'),
#  ('of', 'in'),
#  ('of', 'election'),
#  ('of', 'number'),
#  ('of', 'voters'),
#  ('of', 'the'),
#  ('of', 'size'),
#  ('voters', 'in'),
#  ('voters', 'election'),
#  ('voters', 'number'),
#  ('voters', 'of'),
#  ('voters', 'the'),
#  ('voters', 'size'),
#  ('voters', 'this'),
#  ('the', 'election'),
#  ('the', 'number'),
#  ('the', 'of'),
#  ('the', 'voters'),
#  ('the', 'size'),
#  ('the', 'this'),
#  ('the', 'city'),
#  ('size', 'number'),
#  ('size', 'of'),
#  ('size', 'voters'),
#  ('size', 'the'),
#  ('size', 'this'),
#  ('size', 'city'),
#  ('size', 'jury'),
#  ('this', 'of'),
#  ('this', 'voters'),
#  ('this', 'the'),
#  ('this', 'size'),
#  ('this', 'city'),
#  ('this', 'jury'),
#  ('this', 'said'),
#  ('city', 'voters'),
#  ('city', 'the'),
#  ('city', 'size'),
#  ('city', 'this'),
#  ('city', 'jury'),
#  ('city', 'said'),
#  ('city', 'did'),
#  ('jury', 'the'),
#  ('jury', 'size'),
#  ('jury', 'this'),
#  ('jury', 'city'),
#  ('jury', 'said'),
#  ('jury', 'did'),
#  ('jury', 'find'),
#  ('said', 'size'),
#  ('said', 'this'),
#  ('said', 'city'),
#  ('said', 'jury'),
#  ('said', 'did'),
#  ('said', 'find'),
#  ('said', 'many'),
#  ('did', 'this'),
#  ('did', 'city'),
#  ('did', 'jury'),
#  ('did', 'said'),
#  ('did', 'find'),
#  ('did', 'many'),
#  ('did', 'georgias'),
#  ('find', 'city'),
#  ('find', 'jury'),
#  ('find', 'said'),
#  ('find', 'did'),
#  ('find', 'many'),
#  ('find', 'georgias'),
#  ('find', 'registration'),
#  ('many', 'jury'),
#  ('many', 'said'),
#  ('many', 'did'),
#  ('many', 'find'),
#  ('many', 'georgias'),
#  ('many', 'registration'),
#  ('many', 'and'),
#  ('georgias', 'said'),
#  ('georgias', 'did'),
#  ('georgias', 'find'),
#  ('georgias', 'many'),
#  ('georgias', 'registration'),
#  ('georgias', 'and'),
#  ('georgias', 'election'),
#  ('registration', 'did'),
#  ('registration', 'find'),
#  ('registration', 'many'),
#  ('registration', 'georgias'),
#  ('registration', 'and'),
#  ('registration', 'election'),
#  ('registration', 'laws'),
#  ('and', 'find'),
#  ('and', 'many'),
#  ('and', 'georgias'),
#  ('and', 'registration'),
#  ('and', 'election'),
#  ('and', 'laws'),
#  ('and', 'are'),
#  ('election', 'many'),
#  ('election', 'georgias'),
#  ('election', 'registration'),
#  ('election', 'and'),
#  ('election', 'laws'),
#  ('election', 'are'),
#  ('election', 'outmoded'),
#  ('laws', 'georgias'),
#  ('laws', 'registration'),
#  ('laws', 'and'),
#  ('laws', 'election'),
#  ('laws', 'are'),
#  ('laws', 'outmoded'),
#  ('laws', 'or'),
#  ('are', 'registration'),
#  ('are', 'and'),
#  ('are', 'election'),
#  ('are', 'laws'),
#  ('are', 'outmoded'),
#  ('are', 'or'),
#  ('are', 'inadequate'),
#  ('outmoded', 'and'),
#  ('outmoded', 'election'),
#  ('outmoded', 'laws'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('outmoded', 'inadequate'),
#  ('outmoded', 'often'),
#  ('or', 'election'),
#  ('or', 'laws'),
#  ('or', 'are'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('or', 'often'),
#  ('or', 'ambiguous'),
#  ('inadequate', 'laws'),
#  ('inadequate', 'are'),
#  ('inadequate', 'outmoded'),
#  ('inadequate', 'or'),
#  ('inadequate', 'often'),
#  ('inadequate', 'ambiguous'),
#  ('inadequate', 'it'),
#  ('often', 'are'),
#  ('often', 'outmoded'),
#  ('often', 'or'),
#  ('often', 'inadequate'),
#  ('often', 'ambiguous'),
#  ('often', 'it'),
#  ('often', 'recommended'),
#  ('ambiguous', 'outmoded'),
#  ('ambiguous', 'or'),
#  ('ambiguous', 'inadequate'),
#  ('ambiguous', 'often'),
#  ('ambiguous', 'it'),
#  ('ambiguous', 'recommended'),
#  ('ambiguous', 'that'),
#  ('it', 'or'),
#  ('it', 'inadequate'),
#  ('it', 'often'),
#  ('it', 'ambiguous'),
#  ('it', 'recommended'),
#  ('it', 'that'),
#  ('it', 'fulton'),
#  ('recommended', 'inadequate'),
#  ('recommended', 'often'),
#  ('recommended', 'ambiguous'),
#  ('recommended', 'it'),
#  ('recommended', 'that'),
#  ('recommended', 'fulton'),
#  ('recommended', 'legislators'),
#  ('that', 'often'),
#  ('that', 'ambiguous'),
#  ('that', 'it'),
#  ('that', 'recommended'),
#  ('that', 'fulton'),
#  ('that', 'legislators'),
#  ('that', 'act'),
#  ('fulton', 'ambiguous'),
#  ('fulton', 'it'),
#  ('fulton', 'recommended'),
#  ('fulton', 'that'),
#  ('fulton', 'legislators'),
#  ('fulton', 'act'),
#  ('fulton', 'have'),
#  ('legislators', 'it'),
#  ('legislators', 'recommended'),
#  ('legislators', 'that'),
#  ('legislators', 'fulton'),
#  ('legislators', 'act'),
#  ('legislators', 'have'),
#  ('legislators', 'these'),
#  ('act', 'recommended'),
#  ('act', 'that'),
#  ('act', 'fulton'),
#  ('act', 'legislators'),
#  ('act', 'have'),
#  ('act', 'these'),
#  ('act', 'laws'),
#  ('have', 'that'),
#  ('have', 'fulton'),
#  ('have', 'legislators'),
#  ('have', 'act'),
#  ('have', 'these'),
#  ('have', 'laws'),
#  ('have', 'studied'),
#  ('these', 'fulton'),
#  ('these', 'legislators'),
#  ('these', 'act'),
#  ('these', 'have'),
#  ('these', 'laws'),
#  ('these', 'studied'),
#  ('these', 'revised'),
#  ('laws', 'legislators'),
#  ('laws', 'act'),
#  ('laws', 'have'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('laws', 'revised'),
#  ('laws', 'end'),
#  ('studied', 'act'),
#  ('studied', 'have'),
#  ('studied', 'these'),
#  ('studied', 'laws'),
#  ('studied', 'revised'),
#  ('studied', 'end'),
#  ('studied', 'modernizing'),
#  ('revised', 'have'),
#  ('revised', 'these'),
#  ('revised', 'laws'),
#  ('revised', 'studied'),
#  ('revised', 'end'),
#  ('revised', 'modernizing'),
#  ('revised', 'improving'),
#  ('end', 'these'),
#  ('end', 'laws'),
#  ('end', 'studied'),
#  ('end', 'revised'),
#  ('end', 'modernizing'),
#  ('end', 'improving'),
#  ('end', 'them'),
#  ('modernizing', 'laws'),
#  ('modernizing', 'studied'),
#  ('modernizing', 'revised'),
#  ('modernizing', 'end'),
#  ('modernizing', 'improving'),
#  ('modernizing', 'them'),
#  ('modernizing', 'grand'),
#  ('improving', 'studied'),
#  ('improving', 'revised'),
#  ('improving', 'end'),
#  ('improving', 'modernizing'),
#  ('improving', 'them'),
#  ('improving', 'grand'),
#  ('improving', 'jury'),
#  ('them', 'revised'),
#  ('them', 'end'),
#  ('them', 'modernizing'),
#  ('them', 'improving'),
#  ('them', 'grand'),
#  ('them', 'jury'),
#  ('them', 'commented'),
#  ('grand', 'end'),
#  ('grand', 'modernizing'),
#  ('grand', 'improving'),
#  ('grand', 'them'),
#  ('grand', 'jury'),
#  ('grand', 'commented'),
#  ('grand', 'on'),
#  ('jury', 'modernizing'),
#  ('jury', 'improving'),
#  ('jury', 'them'),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('jury', 'on'),
#  ('jury', 'number'),
#  ('commented', 'improving'),
#  ('commented', 'them'),
#  ('commented', 'grand'),
#  ('commented', 'jury'),
#  ('commented', 'on'),
#  ('commented', 'number'),
#  ('commented', 'other'),
#  ('on', 'them'),
#  ('on', 'grand'),
#  ('on', 'jury'),
#  ('on', 'commented'),
#  ('on', 'number'),
#  ('on', 'other'),
#  ('on', 'topics'),
#  ('number', 'grand'),
#  ('number', 'jury'),
#  ('number', 'commented'),
#  ('number', 'on'),
#  ('number', 'other'),
#  ('number', 'topics'),
#  ('number', 'among'),
#  ('other', 'jury'),
#  ('other', 'commented'),
#  ('other', 'on'),
#  ('other', 'number'),
#  ('other', 'topics'),
#  ('other', 'among'),
#  ('other', 'them'),
#  ('topics', 'commented'),
#  ('topics', 'on'),
#  ('topics', 'number'),
#  ('topics', 'other'),
#  ('topics', 'among'),
#  ('topics', 'them'),
#  ('topics', 'atlanta'),
#  ('among', 'on'),
#  ('among', 'number'),
#  ('among', 'other'),
#  ('among', 'topics'),
#  ('among', 'them'),
#  ('among', 'atlanta'),
#  ('among', 'fulton'),
#  ('them', 'number'),
#  ('them', 'other'),
#  ('them', 'topics'),
#  ('them', 'among'),
#  ('them', 'atlanta'),
#  ('them', 'fulton'),
#  ('them', 'county'),
#  ('atlanta', 'other'),
#  ('atlanta', 'topics'),
#  ('atlanta', 'among'),
#  ('atlanta', 'them'),
#  ('atlanta', 'fulton'),
#  ('atlanta', 'county'),
#  ('atlanta', 'purchasing'),
#  ('fulton', 'topics'),
#  ('fulton', 'among'),
#  ('fulton', 'them'),
#  ('fulton', 'atlanta'),
#  ('fulton', 'county'),
#  ('fulton', 'purchasing'),
#  ('fulton', 'departments'),
#  ('county', 'among'),
#  ('county', 'them'),
#  ('county', 'atlanta'),
#  ('county', 'fulton'),
#  ('county', 'purchasing'),
#  ('county', 'departments'),
#  ('county', 'which'),
#  ('purchasing', 'them'),
#  ('purchasing', 'atlanta'),
#  ('purchasing', 'fulton'),
#  ('purchasing', 'county'),
#  ('purchasing', 'departments'),
#  ('purchasing', 'which'),
#  ('purchasing', 'said'),
#  ('departments', 'atlanta'),
#  ('departments', 'fulton'),
#  ('departments', 'county'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('departments', 'said'),
#  ('departments', 'are'),
#  ('which', 'fulton'),
#  ('which', 'county'),
#  ('which', 'purchasing'),
#  ('which', 'departments'),
#  ('which', 'said'),
#  ('which', 'are'),
#  ('which', 'well'),
#  ('said', 'county'),
#  ('said', 'purchasing'),
#  ('said', 'departments'),
#  ('said', 'which'),
#  ('said', 'are'),
#  ('said', 'well'),
#  ('said', 'operated'),
#  ('are', 'purchasing'),
#  ('are', 'departments'),
#  ('are', 'which'),
#  ('are', 'said'),
#  ('are', 'well'),
#  ('are', 'operated'),
#  ('are', 'and'),
#  ('well', 'departments'),
#  ('well', 'which'),
#  ('well', 'said'),
#  ('well', 'are'),
#  ('well', 'operated'),
#  ('well', 'and'),
#  ('well', 'follow'),
#  ('operated', 'which'),
#  ('operated', 'said'),
#  ('operated', 'are'),
#  ('operated', 'well'),
#  ('operated', 'and'),
#  ('operated', 'follow'),
#  ('operated', 'generally'),
#  ('and', 'said'),
#  ('and', 'are'),
#  ('and', 'well'),
#  ('and', 'operated'),
#  ('and', 'follow'),
#  ('and', 'generally'),
#  ('and', 'accepted'),
#  ('follow', 'are'),
#  ('follow', 'well'),
#  ('follow', 'operated'),
#  ('follow', 'and'),
#  ('follow', 'generally'),
#  ('follow', 'accepted'),
#  ('follow', 'practices'),
#  ('generally', 'well'),
#  ('generally', 'operated'),
#  ('generally', 'and'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('generally', 'practices'),
#  ('generally', 'which'),
#  ('accepted', 'operated'),
#  ('accepted', 'and'),
#  ...]

# %% [markdown]
# ## RNN

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F


class Word2Vec(nn.Module):

    def __init__(self, embedding_size, vocab_size):
        super(Word2Vec, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_size)
        self.linear = nn.Linear(embedding_size, vocab_size)
        
    def forward(self, context_word):
        emb = self.embeddings(context_word)
        hidden = self.linear(emb)
        out = F.log_softmax(hidden)
        return out

# %%
class EarlyStopping():
    def __init__(self, patience=5, min_percent_gain=0.1):
        self.patience = patience
        self.loss_list = []
        self.min_percent_gain = min_percent_gain / 100.
        
    def update_loss(self, loss):
        self.loss_list.append(loss)
        if len(self.loss_list) > self.patience:
            del self.loss_list[0]
    
    def stop_training(self):
        if len(self.loss_list) == 1:
            return False
        gain = (max(self.loss_list) - min(self.loss_list)) / max(self.loss_list)
        print("Loss gain: {}%".format(round(100*gain,2)))
        if gain < self.min_percent_gain:
            return True
        else:
            return False

# %%
vocabulary_size = len(vocabulary)

net = Word2Vec(embedding_size=2, vocab_size=vocabulary_size)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())
early_stopping = EarlyStopping()
context_tensor_list = []

for target, context in context_tuple_list:
    target_tensor = autograd.Variable(torch.LongTensor([word_to_index[target]]))
    context_tensor = autograd.Variable(torch.LongTensor([word_to_index[context]]))
    context_tensor_list.append((target_tensor, context_tensor))
    
while True:
    losses = []
    for target_tensor, context_tensor in context_tensor_list:
        
        net.zero_grad()
        log_probs = net(context_tensor)
        loss = loss_function(log_probs, target_tensor)
        loss.backward()
        optimizer.step()
        losses.append(loss.data)
    print("Loss: ", np.mean(losses))
    early_stopping.update_loss(np.mean(losses))
    if early_stopping.stop_training():
        break
# Out:
# <ipython-input-18-9856d2df2c28>:18: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.log_softmax(hidden)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-947343836532> in <module>
#      19         log_probs = net(context_tensor)
#      20         loss = loss_function(log_probs, target_tensor)
# ---> 21         loss.backward()
#      22         optimizer.step()
#      23         losses.append(loss.data)
#
# ~/.local/share/virtualenvs/pytorch-m37tbeE3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/.local/share/virtualenvs/pytorch-m37tbeE3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      95         retain_graph = create_graph
#      96
# ---> 97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
#      99         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ## speed up version

# %%
import random

def get_batches(context_tuple_list, batch_size=100):
    random.shuffle(context_tuple_list)
    batches = []
    batch_target, batch_context, batch_negative = [], [], []
    for i in range(len(context_tuple_list)):
        batch_target.append(word_to_index[context_tuple_list[i][0]])
        batch_context.append(word_to_index[context_tuple_list[i][1]])
        batch_negative.append([word_to_index[w] for w in context_tuple_list[i][2]])
        if (i+1) % batch_size == 0 or i == len(context_tuple_list)-1:
            tensor_target = autograd.Variable(torch.from_numpy(np.array(batch_target)).long())
            tensor_context = autograd.Variable(torch.from_numpy(np.array(batch_context)).long())
            tensor_negative = autograd.Variable(torch.from_numpy(np.array(batch_negative)).long())
            batches.append((tensor_target, tensor_context, tensor_negative))
            batch_target, batch_context, batch_negative = [], [], []
    return batches

# %%
from numpy.random import multinomial

def sample_negative(sample_size):
    sample_probability = {}
    word_counts = dict(Counter(list(itertools.chain.from_iterable(corpus))))
    normalizing_factor = sum([v**0.75 for v in word_counts.values()])
    for word in word_counts:
        sample_probability[word] = word_counts[word]**0.75 / normalizing_factor
    words = np.array(list(word_counts.keys()))
    while True:
        word_list = []
        sampled_index = np.array(multinomial(sample_size, list(sample_probability.values())))
        for index, count in enumerate(sampled_index):
            for _ in range(count):
                 word_list.append(words[index])
        yield word_list

# %%
def get_closest_word(word, topn=5):
    word_distance = []
    emb = net.embeddings_target
    pdist = nn.PairwiseDistance()
    i = word_to_index[word]
    lookup_tensor_i = torch.tensor([i], dtype=torch.long)
    v_i = emb(lookup_tensor_i)
    for j in range(len(vocabulary)):
        if j != i:
            lookup_tensor_j = torch.tensor([j], dtype=torch.long)
            v_j = emb(lookup_tensor_j)
            word_distance.append((index_to_word[j], float(pdist(v_i, v_j))))
    word_distance.sort(key=lambda x: x[1])
    return word_distance[:topn]

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F


class Word2Vec(nn.Module):

    def __init__(self, embedding_size, vocab_size):
        super(Word2Vec, self).__init__()
        self.embeddings_target = nn.Embedding(vocab_size, embedding_size)
        self.embeddings_context = nn.Embedding(vocab_size, embedding_size)

    def forward(self, target_word, context_word, negative_example):
        emb_target = self.embeddings_target(target_word)
        emb_context = self.embeddings_context(context_word)
        emb_product = torch.mul(emb_target, emb_context)
        emb_product = torch.sum(emb_product, dim=1)
        out = torch.sum(F.logsigmoid(emb_product))
        emb_negative = self.embeddings_context(negative_example)
        emb_product = torch.bmm(emb_negative, emb_target.unsqueeze(2))
        emb_product = torch.sum(emb_product, dim=1)
        out += torch.sum(F.logsigmoid(-emb_product))
        return -out

# %%
import time

vocabulary_size = len(vocabulary)

loss_function = nn.CrossEntropyLoss()
net = Word2Vec(embedding_size=200, vocab_size=vocabulary_size)
optimizer = optim.Adam(net.parameters())
early_stopping = EarlyStopping(patience=5, min_percent_gain=1)
print(context_tuple_list)
get_batches(context_tuple_list, batch_size=2000)
while True:
    losses = []
    context_tuple_batches = get_batches(context_tuple_list, batch_size=2000)
    for i in range(len(context_tuple_batches)):
        net.zero_grad()
        target_tensor, context_tensor, negative_tensor = context_tuple_batches[i]
        loss = net(target_tensor, context_tensor, negative_tensor)
        loss.backward()
        optimizer.step()
        losses.append(loss.data)
    print("Loss: ", np.mean(losses))
    early_stopping.update_loss(np.mean(losses))
    if early_stopping.stop_training():
        break
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-4f5b75f6ebe0> in <module>
#       8 early_stopping = EarlyStopping(patience=5, min_percent_gain=1)
#       9 print(context_tuple_list)
# ---> 10 get_batches(context_tuple_list, batch_size=2000)
#      11 while True:
#      12     losses = []
#
# <ipython-input-9-96d9bcda3ed8> in get_batches(context_tuple_list, batch_size)
#       8         batch_target.append(word_to_index[context_tuple_list[i][0]])
#       9         batch_context.append(word_to_index[context_tuple_list[i][1]])
# ---> 10         batch_negative.append([word_to_index[w] for w in context_tuple_list[i][2]])
#      11         if (i+1) % batch_size == 0 or i == len(context_tuple_list)-1:
#      12             tensor_target = autograd.Variable(torch.from_numpy(np.array(batch_target)).long())
#
# IndexError: tuple index out of range
